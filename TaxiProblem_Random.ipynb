# %% [markdown]
# # **SIT 215 - Project**
#
# # **Investigating Reinforcement Learning**
#
# ## Taxi Problem - Random Agent
#
# ### Mir Muhammad Sohaib
# ### 220576368

# %% [markdown]
# # 1. Dependencies

# %% [markdown]
# ## 1.1. Installing dependencies

# %%
# For using Open AI Gym
# !pip install gym 

# For visualising Open AI Gym
# !pip install pygame
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gym in /usr/local/lib/python3.7/dist-packages (0.17.3)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym) (1.5.0)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym) (1.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym) (1.4.1)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from gym) (1.21.6)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym) (0.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pygame
#   Downloading pygame-2.1.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21.8 MB)
#      |████████████████████████████████| 21.8 MB 1.4 MB/s
# Installing collected packages: pygame
# Successfully installed pygame-2.1.2

# %% [markdown]
# ## 1.2. Importing relevant libraries

# %%
# Importing relevant libraries 
import gym 
from random import random, uniform 
import math  
import numpy as np                                 
from random import random 
import matplotlib                          
import matplotlib.pyplot as plt

# %% [markdown]
# # 2. Random Agent

# %%
# Random Agent
class Random():
    def __init__(self):
        super().__init__()

    # The training action is any random action from within the environment action space
    def action(self, env):
        return env.action_space.sample()

# %% [markdown]
# # 3. Driver Class (Helper Methods)

# %%
class Driver:

    # Initialise
    def __init__(self, params):
        self.epochs = params['epochs']
        self.env = params['env']
        self.agent = params['agent']
        self.training_rewards = []
        self.evaluation_rewards = []

    # Run random
    def run_taxi_random(self):
        training_action = lambda _observation: self.agent.action(self.env)
        update = lambda _observation, _action, _reward: None
        evaluation_action = training_action

        self.run(training_action, update, evaluation_action)
        
    # Training and evaluation loop, plots then demonstrate
    def run(self, training_action, update, evaluation_action):
        for i in range(self.epochs):
            if ((i + 1) % 1000 == 0):
                print("Progress: {}%".format(100 * (i + 1) // self.epochs))
            self.train_once(training_action, update)
            self.evaluate_once(evaluation_action)

        self.plot()
        
        try:
            self.demonstrate(evaluation_action)
        except NotImplementedError:
            print("Cannot demonstrate: render method on env not implemented.")

    # A single instance of training of the agent in the environment
    def train_once(self, training_action, update):
        observation = self.env.reset()
        done = False
        episode_reward = 0
        while not done:
            action = training_action(observation)
            observation, reward, done, info = self.env.step(action)
            episode_reward += reward
            update(observation, action, reward)
        self.training_rewards.append(episode_reward)

    # A single instance of evaluation of the agent at it's current level of training
    def evaluate_once(self, evaluation_action):
        observation = self.env.reset()
        done = False
        episode_reward = 0
        while not done:
            action = evaluation_action(observation)
            observation, reward, done, info = self.env.step(action)
            episode_reward += reward
        self.evaluation_rewards.append(episode_reward)

    # Plot the training and evaluation reward levels at each epoch
    def plot(self):
        plt.subplot('211')
        plt.plot(self.training_rewards, linewidth=1)
        plt.title('Training reward over time')
        plt.ylabel('Reward')
        plt.xlabel('Iterations')

        plt.subplot('212')
        plt.plot(self.evaluation_rewards, linewidth=1)
        plt.title('Evaluation reward over time')
        plt.ylabel('Reward')
        plt.xlabel('Iterations')
        plt.tight_layout()
        plt.show()
        
    # Use the environments render method and print some additional info to the console. permit user input for repeated demonstrations in a loop
    def demonstrate(self, evaluation_action):
            observation = self.env.reset()
            done = False
            episode_reward = 0
            reward = 0
            step = 0
            while not done:
                print(f"Step: {step} | Cumulative Reward: {episode_reward}")
                step += 1
                print("RENDERING:")
                self.env.render()
                action = evaluation_action(observation)
                print('Observation: ', observation)
                print('Action: ', action)
                print('Reward: ', reward)
                observation, reward, done, info = self.env.step(action)
                episode_reward += reward

# %% [markdown]
# # 4. Results

# %%
# Providing parameter values to the agent and driver
def taxi_random():
    agent = Random()
    driver = Driver({
        'epochs': 1000,
        'env': gym.make('Taxi-v3'),
        'agent': agent,
    })
    driver.run_taxi_random()

if __name__ == '__main__':
    taxi_random()
# Out:
# Progress: 100%
# Step: 0 | Cumulative Reward: 0
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
# Observation:  72
# Action:  3
# Reward:  0
# Step: 1 | Cumulative Reward: -1
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# Observation:  52
# Action:  5
# Reward:  -1
# Step: 2 | Cumulative Reward: -11
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# Observation:  52
# Action:  2
# Reward:  -10
# Step: 3 | Cumulative Reward: -12
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# Observation:  72
# Action:  3
# Reward:  -1
# Step: 4 | Cumulative Reward: -13
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# Observation:  52
# Action:  5
# Reward:  -1
# Step: 5 | Cumulative Reward: -23
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# Observation:  52
# Action:  0
# Reward:  -10
# Step: 6 | Cumulative Reward: -24
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Observation:  152
# Action:  5
# Reward:  -1
# Step: 7 | Cumulative Reward: -34
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# Observation:  152
# Action:  5
# Reward:  -10
# Step: 8 | Cumulative Reward: -44
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# Observation:  152
# Action:  0
# Reward:  -10
# Step: 9 | Cumulative Reward: -45
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Observation:  252
# Action:  5
# Reward:  -1
# Step: 10 | Cumulative Reward: -55
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# Observation:  252
# Action:  4
# Reward:  -10
# Step: 11 | Cumulative Reward: -65
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# Observation:  252
# Action:  2
# Reward:  -10
# Step: 12 | Cumulative Reward: -66
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# Observation:  272
# Action:  3
# Reward:  -1
# Step: 13 | Cumulative Reward: -67
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# Observation:  252
# Action:  1
# Reward:  -1
# Step: 14 | Cumulative Reward: -68
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# Observation:  152
# Action:  5
# Reward:  -1
# Step: 15 | Cumulative Reward: -78
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# Observation:  152
# Action:  1
# Reward:  -10
# Step: 16 | Cumulative Reward: -79
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# Observation:  52
# Action:  5
# Reward:  -1
# Step: 17 | Cumulative Reward: -89
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# Observation:  52
# Action:  1
# Reward:  -10
# Step: 18 | Cumulative Reward: -90
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# Observation:  52
# Action:  2
# Reward:  -1
# Step: 19 | Cumulative Reward: -91
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# Observation:  72
# Action:  5
# Reward:  -1
# Step: 20 | Cumulative Reward: -101
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# Observation:  72
# Action:  4
# Reward:  -10
# Step: 21 | Cumulative Reward: -111
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# Observation:  72
# Action:  5
# Reward:  -10
# Step: 22 | Cumulative Reward: -121
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# Observation:  72
# Action:  0
# Reward:  -10
# Step: 23 | Cumulative Reward: -122
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Observation:  172
# Action:  1
# Reward:  -1
# Step: 24 | Cumulative Reward: -123
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# Observation:  72
# Action:  3
# Reward:  -1
# Step: 25 | Cumulative Reward: -124
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# Observation:  52
# Action:  2
# Reward:  -1
# Step: 26 | Cumulative Reward: -125
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# Observation:  72
# Action:  5
# Reward:  -1
# Step: 27 | Cumulative Reward: -135
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# Observation:  72
# Action:  5
# Reward:  -10
# Step: 28 | Cumulative Reward: -145
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# Observation:  72
# Action:  2
# Reward:  -10
# Step: 29 | Cumulative Reward: -146
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# Observation:  92
# Action:  4
# Reward:  -1
# Step: 30 | Cumulative Reward: -156
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# Observation:  92
# Action:  4
# Reward:  -10
# Step: 31 | Cumulative Reward: -166
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# Observation:  92
# Action:  1
# Reward:  -10
# Step: 32 | Cumulative Reward: -167
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# Observation:  92
# Action:  1
# Reward:  -1
# Step: 33 | Cumulative Reward: -168
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# Observation:  92
# Action:  4
# Reward:  -1
# Step: 34 | Cumulative Reward: -178
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# Observation:  92
# Action:  1
# Reward:  -10
# Step: 35 | Cumulative Reward: -179
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# Observation:  92
# Action:  2
# Reward:  -1
# Step: 36 | Cumulative Reward: -180
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# Observation:  92
# Action:  3
# Reward:  -1
# Step: 37 | Cumulative Reward: -181
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# Observation:  72
# Action:  5
# Reward:  -1
# Step: 38 | Cumulative Reward: -191
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# Observation:  72
# Action:  1
# Reward:  -10
# Step: 39 | Cumulative Reward: -192
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# Observation:  72
# Action:  1
# Reward:  -1
# Step: 40 | Cumulative Reward: -193
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# Observation:  72
# Action:  4
# Reward:  -1
# Step: 41 | Cumulative Reward: -203
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# Observation:  72
# Action:  2
# Reward:  -10
# Step: 42 | Cumulative Reward: -204
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# Observation:  92
# Action:  3
# Reward:  -1
# Step: 43 | Cumulative Reward: -205
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# Observation:  72
# Action:  2
# Reward:  -1
# Step: 44 | Cumulative Reward: -206
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# Observation:  92
# Action:  1
# Reward:  -1
# Step: 45 | Cumulative Reward: -207
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# Observation:  92
# Action:  0
# Reward:  -1
# Step: 46 | Cumulative Reward: -208
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Observation:  192
# Action:  4
# Reward:  -1
# Step: 47 | Cumulative Reward: -218
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# Observation:  192
# Action:  4
# Reward:  -10
# Step: 48 | Cumulative Reward: -228
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# Observation:  192
# Action:  2
# Reward:  -10
# Step: 49 | Cumulative Reward: -229
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# Observation:  192
# Action:  0
# Reward:  -1
# Step: 50 | Cumulative Reward: -230
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Observation:  292
# Action:  5
# Reward:  -1
# Step: 51 | Cumulative Reward: -240
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# Observation:  292
# Action:  2
# Reward:  -10
# Step: 52 | Cumulative Reward: -241
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# Observation:  292
# Action:  3
# Reward:  -1
# Step: 53 | Cumulative Reward: -242
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# Observation:  272
# Action:  5
# Reward:  -1
# Step: 54 | Cumulative Reward: -252
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# Observation:  272
# Action:  4
# Reward:  -10
# Step: 55 | Cumulative Reward: -262
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# Observation:  272
# Action:  4
# Reward:  -10
# Step: 56 | Cumulative Reward: -272
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# Observation:  272
# Action:  0
# Reward:  -10
# Step: 57 | Cumulative Reward: -273
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Observation:  372
# Action:  4
# Reward:  -1
# Step: 58 | Cumulative Reward: -283
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# Observation:  372
# Action:  3
# Reward:  -10
# Step: 59 | Cumulative Reward: -284
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# Observation:  372
# Action:  0
# Reward:  -1
# Step: 60 | Cumulative Reward: -285
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Observation:  472
# Action:  4
# Reward:  -1
# Step: 61 | Cumulative Reward: -286
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# Observation:  476
# Action:  2
# Reward:  -1
# Step: 62 | Cumulative Reward: -287
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B:_|
# +---------+
#   (East)
# Observation:  496
# Action:  1
# Reward:  -1
# Step: 63 | Cumulative Reward: -288
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | :_|
# |Y| : |B: |
# +---------+
#   (North)
# Observation:  396
# Action:  3
# Reward:  -1
# Step: 64 | Cumulative Reward: -289
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : |_: |
# |Y| : |B: |
# +---------+
#   (West)
# Observation:  376
# Action:  5
# Reward:  -1
# Step: 65 | Cumulative Reward: -299
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : |_: |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# Observation:  376
# Action:  2
# Reward:  -10
# Step: 66 | Cumulative Reward: -300
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | :_|
# |Y| : |B: |
# +---------+
#   (East)
# Observation:  396
# Action:  0
# Reward:  -1
# Step: 67 | Cumulative Reward: -301
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B:_|
# +---------+
#   (South)
# Observation:  496
# Action:  1
# Reward:  -1
# Step: 68 | Cumulative Reward: -302
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | :_|
# |Y| : |B: |
# +---------+
#   (North)
# Observation:  396
# Action:  1
# Reward:  -1
# Step: 69 | Cumulative Reward: -303
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : :_|
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# Observation:  296
# Action:  2
# Reward:  -1
# Step: 70 | Cumulative Reward: -304
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : :_|
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# Observation:  296
# Action:  0
# Reward:  -1
# Step: 71 | Cumulative Reward: -305
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | :_|
# |Y| : |B: |
# +---------+
#   (South)
# Observation:  396
# Action:  1
# Reward:  -1
# Step: 72 | Cumulative Reward: -306
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : :_|
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# Observation:  296
# Action:  4
# Reward:  -1
# Step: 73 | Cumulative Reward: -316
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : :_|
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# Observation:  296
# Action:  2
# Reward:  -10
# Step: 74 | Cumulative Reward: -317
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : :_|
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# Observation:  296
# Action:  4
# Reward:  -1
# Step: 75 | Cumulative Reward: -327
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : :_|
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# Observation:  296
# Action:  4
# Reward:  -10
# Step: 76 | Cumulative Reward: -337
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : :_|
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# Observation:  296
# Action:  4
# Reward:  -10
# Step: 77 | Cumulative Reward: -347
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : :_|
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# Observation:  296
# Action:  3
# Reward:  -10
# Step: 78 | Cumulative Reward: -348
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : :_: |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# Observation:  276
# Action:  0
# Reward:  -1
# Step: 79 | Cumulative Reward: -349
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : |_: |
# |Y| : |B: |
# +---------+
#   (South)
# Observation:  376
# Action:  3
# Reward:  -1
# Step: 80 | Cumulative Reward: -350
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : |_: |
# |Y| : |B: |
# +---------+
#   (West)
# Observation:  376
# Action:  5
# Reward:  -1
# Step: 81 | Cumulative Reward: -360
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : |_: |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# Observation:  376
# Action:  2
# Reward:  -10
# Step: 82 | Cumulative Reward: -361
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | :_|
# |Y| : |B: |
# +---------+
#   (East)
# Observation:  396
# Action:  1
# Reward:  -1
# Step: 83 | Cumulative Reward: -362
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : :_|
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# Observation:  296
# Action:  1
# Reward:  -1
# Step: 84 | Cumulative Reward: -363
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : :_|
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# Observation:  196
# Action:  4
# Reward:  -1
# Step: 85 | Cumulative Reward: -373
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : :_|
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# Observation:  196
# Action:  2
# Reward:  -10
# Step: 86 | Cumulative Reward: -374
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : :_|
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# Observation:  196
# Action:  0
# Reward:  -1
# Step: 87 | Cumulative Reward: -375
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : :_|
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Observation:  296
# Action:  0
# Reward:  -1
# Step: 88 | Cumulative Reward: -376
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | :_|
# |Y| : |B: |
# +---------+
#   (South)
# Observation:  396
# Action:  4
# Reward:  -1
# Step: 89 | Cumulative Reward: -386
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | :_|
# |Y| : |B: |
# +---------+
#   (Pickup)
# Observation:  396
# Action:  1
# Reward:  -10
# Step: 90 | Cumulative Reward: -387
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : :_|
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# Observation:  296
# Action:  4
# Reward:  -1
# Step: 91 | Cumulative Reward: -397
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : :_|
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# Observation:  296
# Action:  0
# Reward:  -10
# Step: 92 | Cumulative Reward: -398
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | :_|
# |Y| : |B: |
# +---------+
#   (South)
# Observation:  396
# Action:  2
# Reward:  -1
# Step: 93 | Cumulative Reward: -399
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | :_|
# |Y| : |B: |
# +---------+
#   (East)
# Observation:  396
# Action:  4
# Reward:  -1
# Step: 94 | Cumulative Reward: -409
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | :_|
# |Y| : |B: |
# +---------+
#   (Pickup)
# Observation:  396
# Action:  5
# Reward:  -10
# Step: 95 | Cumulative Reward: -419
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | :_|
# |Y| : |B: |
# +---------+
#   (Dropoff)
# Observation:  396
# Action:  0
# Reward:  -10
# Step: 96 | Cumulative Reward: -420
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B:_|
# +---------+
#   (South)
# Observation:  496
# Action:  1
# Reward:  -1
# Step: 97 | Cumulative Reward: -421
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | :_|
# |Y| : |B: |
# +---------+
#   (North)
# Observation:  396
# Action:  3
# Reward:  -1
# Step: 98 | Cumulative Reward: -422
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : |_: |
# |Y| : |B: |
# +---------+
#   (West)
# Observation:  376
# Action:  4
# Reward:  -1
# Step: 99 | Cumulative Reward: -432
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : |_: |
# |Y| : |B: |
# +---------+
#   (Pickup)
# Observation:  376
# Action:  1
# Reward:  -10
# Step: 100 | Cumulative Reward: -433
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : :_: |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# Observation:  276
# Action:  4
# Reward:  -1
# Step: 101 | Cumulative Reward: -443
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : :_: |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# Observation:  276
# Action:  1
# Reward:  -10
# Step: 102 | Cumulative Reward: -444
# RENDERING:
# +---------+
# |R: | : :G|
# | : | :_: |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# Observation:  176
# Action:  0
# Reward:  -1
# Step: 103 | Cumulative Reward: -445
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : :_: |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Observation:  276
# Action:  0
# Reward:  -1
# Step: 104 | Cumulative Reward: -446
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : |_: |
# |Y| : |B: |
# +---------+
#   (South)
# Observation:  376
# Action:  4
# Reward:  -1
# Step: 105 | Cumulative Reward: -456
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : |_: |
# |Y| : |B: |
# +---------+
#   (Pickup)
# Observation:  376
# Action:  2
# Reward:  -10
# Step: 106 | Cumulative Reward: -457
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | :_|
# |Y| : |B: |
# +---------+
#   (East)
# Observation:  396
# Action:  4
# Reward:  -1
# Step: 107 | Cumulative Reward: -467
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | :_|
# |Y| : |B: |
# +---------+
#   (Pickup)
# Observation:  396
# Action:  4
# Reward:  -10
# Step: 108 | Cumulative Reward: -477
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | :_|
# |Y| : |B: |
# +---------+
#   (Pickup)
# Observation:  396
# Action:  5
# Reward:  -10
# Step: 109 | Cumulative Reward: -487
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | :_|
# |Y| : |B: |
# +---------+
#   (Dropoff)
# Observation:  396
# Action:  2
# Reward:  -10
# Step: 110 | Cumulative Reward: -488
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | :_|
# |Y| : |B: |
# +---------+
#   (East)
# Observation:  396
# Action:  1
# Reward:  -1
# Step: 111 | Cumulative Reward: -489
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : :_|
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# Observation:  296
# Action:  4
# Reward:  -1
# Step: 112 | Cumulative Reward: -499
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : :_|
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# Observation:  296
# Action:  1
# Reward:  -10
# Step: 113 | Cumulative Reward: -500
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : :_|
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# Observation:  196
# Action:  4
# Reward:  -1
# Step: 114 | Cumulative Reward: -510
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : :_|
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# Observation:  196
# Action:  1
# Reward:  -10
# Step: 115 | Cumulative Reward: -511
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# Observation:  96
# Action:  1
# Reward:  -1
# Step: 116 | Cumulative Reward: -512
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# Observation:  96
# Action:  3
# Reward:  -1
# Step: 117 | Cumulative Reward: -513
# RENDERING:
# +---------+
# |R: | :_:G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# Observation:  76
# Action:  2
# Reward:  -1
# Step: 118 | Cumulative Reward: -514
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# Observation:  96
# Action:  1
# Reward:  -1
# Step: 119 | Cumulative Reward: -515
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# Observation:  96
# Action:  4
# Reward:  -1
# Step: 120 | Cumulative Reward: -525
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# Observation:  96
# Action:  0
# Reward:  -10
# Step: 121 | Cumulative Reward: -526
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : :_|
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Observation:  196
# Action:  0
# Reward:  -1
# Step: 122 | Cumulative Reward: -527
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : :_|
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Observation:  296
# Action:  1
# Reward:  -1
# Step: 123 | Cumulative Reward: -528
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : :_|
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# Observation:  196
# Action:  1
# Reward:  -1
# Step: 124 | Cumulative Reward: -529
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# Observation:  96
# Action:  2
# Reward:  -1
# Step: 125 | Cumulative Reward: -530
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# Observation:  96
# Action:  0
# Reward:  -1
# Step: 126 | Cumulative Reward: -531
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : :_|
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Observation:  196
# Action:  3
# Reward:  -1
# Step: 127 | Cumulative Reward: -532
# RENDERING:
# +---------+
# |R: | : :G|
# | : | :_: |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# Observation:  176
# Action:  0
# Reward:  -1
# Step: 128 | Cumulative Reward: -533
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : :_: |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Observation:  276
# Action:  5
# Reward:  -1
# Step: 129 | Cumulative Reward: -543
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : :_: |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# Observation:  276
# Action:  3
# Reward:  -10
# Step: 130 | Cumulative Reward: -544
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : :_: : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# Observation:  256
# Action:  1
# Reward:  -1
# Step: 131 | Cumulative Reward: -545
# RENDERING:
# +---------+
# |R: | : :G|
# | : |_: : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# Observation:  156
# Action:  4
# Reward:  -1
# Step: 132 | Cumulative Reward: -555
# RENDERING:
# +---------+
# |R: | : :G|
# | : |_: : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# Observation:  156
# Action:  0
# Reward:  -10
# Step: 133 | Cumulative Reward: -556
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : :_: : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Observation:  256
# Action:  3
# Reward:  -1
# Step: 134 | Cumulative Reward: -557
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | :_: : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# Observation:  236
# Action:  1
# Reward:  -1
# Step: 135 | Cumulative Reward: -558
# RENDERING:
# +---------+
# |R: | : :G|
# | :_| : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# Observation:  136
# Action:  3
# Reward:  -1
# Step: 136 | Cumulative Reward: -559
# RENDERING:
# +---------+
# |R: | : :G|
# |_: | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# Observation:  116
# Action:  3
# Reward:  -1
# Step: 137 | Cumulative Reward: -560
# RENDERING:
# +---------+
# |R: | : :G|
# |_: | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# Observation:  116
# Action:  4
# Reward:  -1
# Step: 138 | Cumulative Reward: -570
# RENDERING:
# +---------+
# |R: | : :G|
# |_: | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# Observation:  116
# Action:  5
# Reward:  -10
# Step: 139 | Cumulative Reward: -580
# RENDERING:
# +---------+
# |R: | : :G|
# |_: | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# Observation:  116
# Action:  1
# Reward:  -10
# Step: 140 | Cumulative Reward: -581
# RENDERING:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# Observation:  16
# Action:  5
# Reward:  -1
